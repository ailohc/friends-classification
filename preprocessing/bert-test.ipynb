# %%
import os
import numpy as np
import re
import pandas as pd
from chatspace import ChatSpace

# %%
DEFAULT_PATH='./../data/'
TEST_PATH = os.path.join(DEFAULT_PATH, 'en_data.csv')

# %%
import pandas as pd
from io import StringIO
import re

for_pd = StringIO()
with open(TEST_PATH, encoding="utf8", errors='ignore') as mike:
    for line in mike:
        new_line = re.sub(r',', '|', line.rstrip(), count=4)
        print (new_line, file=for_pd)

for_pd.seek(0)
# Out:
# 0

# %%
test = pd.read_csv(for_pd, sep='|', header=0)

# %%
del test['id']
del test['i_dialog']
del test['i_utterance']
del test['speaker']

# %%
test
# Out:
#                                               utterance
# 0                         Alright, whadyou do with him?
# 1                                     Oh! You're awake!
# 2     Then you gotta come clean with Ma! This is not...
# 3                                     Yeah, but this is
# 4             I don't wanna hear it! Now go to my room!
# ...                                                 ...
# 3291                                           I guess.
# 3292  So, shouldn?t we go give her the benefit of th...
# 3293  Fine. I?m just glad I didn?t give her my secre...
# 3294  Out of curiosity, what is your secret ingredient?
# 3295                                              Yeah!
#
# [3296 rows x 1 columns]

# %%
with open(os.path.join(DEFAULT_PATH, 'test.txt'), "a") as f:
    for index, row in test.iterrows():
        orig_utterance = row[0]
        cleaned_utterance = re.sub(u'"',u"", orig_utterance)
        cleaned_utterance = re.sub(u'’',u"'", cleaned_utterance)

        line = cleaned_utterance
        print(line)

        f.write(line + '\n')
# Out:
# Alright, whadyou do with him?
# Oh! You're awake!
# Then you gotta come clean with Ma! This is not right!
# Yeah, but this is
# I don't wanna hear it! Now go to my room!
# I don?t want him to tell this story for years.
# Oh, but he will. He still tells the story how Monica tried to escape from fat camp.
# I wasn?t escaping.
# Then how did you get caught in the barbed wire?
# I was trying to help out a squirrel.
# You were trying to eat it!
# If
# Come on.  Hello?  I?m sorry you have the wrong number.   Okay, I?ll call you later dad. I love you.
# I was thinking of doing it a little shorter, you know, like Andie McDowell's new haircut?
# Oh yeah!? Oh, I can do that.
# Really?
# I'm sorry. I am such a doofus. I'm so sorry, I'm so sorry.
# My god, what happened?
# These new kids, they never last.
# Sooner or later, they all...stop lastin'.
# Listen, uh, what do you say I buy you that cup of coffee now?
# Sure.
# Oh my God Phoebe, you?re on fire!
# I know!
# ...

# %%
test
# Out:
#                                               utterance
# 0                         Alright, whadyou do with him?
# 1                                     Oh! You're awake!
# 2     Then you gotta come clean with Ma! This is not...
# 3                                     Yeah, but this is
# 4             I don't wanna hear it! Now go to my room!
# ...                                                 ...
# 3291                                           I guess.
# 3292  So, shouldn?t we go give her the benefit of th...
# 3293  Fine. I?m just glad I didn?t give her my secre...
# 3294  Out of curiosity, what is your secret ingredient?
# 3295                                              Yeah!
#
# [3296 rows x 1 columns]
